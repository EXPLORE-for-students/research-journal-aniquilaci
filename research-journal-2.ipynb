# %% [markdown]
# # Research Notebook
# ## Reamonn Franky James Leitzig
# ## Date: 11.02.2026

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# - Reading "An Enhanced Isothermal Jeans Approach to Constraining Dark Matter Self-Interactions from Galactic Kinematics" [1]
#
# - Informing about emcee [3]
#
# - Plotting functions with the jeans model with different M_200 and c values. The M_200 should be in the range from 10^8 to 10^14 and c in the range of 1 to 20.
#
# - Writing a function which sorts the SPARC Galaxies in those who are usable for later analyses and others which are not usable.
#
#
# ## Motivation:
#
# - Its important for later to see how the plots with a jeans model differ from each other for different c and M_200 variables. Its also important to see how they work.
#
# - For later steps its important to have good data to work with. Not all SPARC galaxies are good enough for further steps later on. Its important to exclude galaxies without enough data, in this case under eight data points. Its important to use galaxies with good data. Later on galaxies are excluded with V_vir / V_max >= 1 (see [1] under 3.1 Sample selection).

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# - The galaxy UGCA442 was selected for the jeans fit. It was not possible to get a good jeans fit with my first selected galaxy KK98-251 and with Phi_b = None as shown later. The first data points worked well, but the fit is to linear for the later data points.
#
# - The next following code is for the plots for the Galaxy UGCA442:
#
# """
# r1 = 20 # in kpc
# M200 = 1e11 # in solar masses
# c = 13 # concentration parameter
#
# Phi_b = None
#
# profile = jeans.squashed(r1, M200, c, Phi_b=Phi_b, verbose=True)
#
# plt.figure(figsize=(6,4))
# plt.errorbar(df['Rad'], df['Vobs'], yerr=df['errV'], fmt='o', label='Observed', color='black', markersize=5)
# plt.plot(df['Rad'], profile.V(df['Rad'], Lmax=0), label='Jeans Model', color='C0')
#
#
# plt.xlabel(f"Radius ({units.at[0, 'Rad']})")
# plt.ylabel(f"Velocity ({units.at[0, 'Vobs']})")
# plt.title(f"Rotation Curve for UGCA442 (Distance: {dist} Mpc)")
# plt.legend()
# plt.grid()
# plt.show()
# print("The choosen parameters are", M200, "for the M200 in solar masses and", c, "for the concentration parameter c. Phi_b is None.")
# """
#
# - The best working fit for this galaxy with Phi_b = None was c = 13 and M200 = 1e11.
#
# - A second code with a c, related to M200 was used for the plots. Here, we use different M200, r1 and still Phi_b = None. The mass concentration relation is by Dutton and Maccio 2014 [5]. It is the following code:
#
# """
# #c from mass-concentration relation (Dutton & Maccio, 2014)
#
# M200 = 1e13 # in solar masses
# def c_MCR(M200):
#     a, b = 0.905, -0.101
#     h = 0.7
#     c = 10**(a + b*np.log10(h*M200/1e12))
#
#     return c
#
#
#
#
# r1 = 4.35 # in kpc
# Phi_b = None
#
# profile = jeans.squashed(r1, M200, c, Phi_b=Phi_b, verbose=True)
#
# plt.figure(figsize=(6,4))
# plt.errorbar(df['Rad'], df['Vobs'], yerr=df['errV'], fmt='o', label='Observed', color='black', markersize=5)
# plt.plot(df['Rad'], profile.V(df['Rad'], Lmax=0), label='Jeans Model', color='C0')
#
#
# plt.xlabel(f"Radius ({units.at[0, 'Rad']})")
# plt.ylabel(f"Velocity ({units.at[0, 'Vobs']})")
# plt.title(f"Rotation Curve for UGCA442 (Distance: {dist} Mpc)")
# plt.legend()
# plt.grid()
# plt.show()
#
# """
#
# - The next eight pgn are all plots. The first seven galaxies are UGCA442 and the eighth one is KK98-251
#
# - Plot 1: Phi_b = None; c = 13; M200 = 1e11; r1 = 20
# - Plot 2: Phi_b = None; c = 11; M200 = 1e12; r1 = 20
# - Plot 3: Phi_b = None; c = 1; M200 = 1e13; r1 = 20
# - Plot 4: Phi_b = None; c related to M200; M200 = 1e11; r1 = 10
# - Plot 5: Phi_b = None; c related to M200; M200 = 1e12; r1 = 10
# - Plot 6: Phi_b = None; c related to M200; M200 = 1e13; r1 = 10
# - Plot 7: Phi_b = None; c related to M200; M200 = 1e13; r1 = 4.35
# - Plot 8: Phi_b = None; c = 13; M200 = 1e11; r1 = 20; Galaxy KK98-251
#
#
# ![UGCA442_jeans_1.png]
# ![UGCA442_jeans_2.png]
# ![UGCA442_jeans_3.png]
# ![UGCA442_jeans_4.png]
# ![UGCA442_jeans_5.png]
# ![UGCA442_jeans_6.png]
# ![UGCA442_jeans_7.png]
# ![KK98-251_jeans_8.png]
#
# - The next code is for excluding galaxies under eight data points
#
# """
# passed_galaxies = []
# excluded_galaxies = []
#
# galaxy_ids = get_galaxy_ids()
#
# for galaxy_id in galaxy_ids:
#     df, _, _ = get_rc_data(galaxy_id)
#
#     print("The galaxy", galaxy_id, "has a length of", len(df))
#
#     if len(df) < 8:
#         print("Remove galaxy", galaxy_id)
#         excluded_galaxies.append(galaxy_id)
#     else:
#         print("The galaxy", galaxy_id, "passed")
#         passed_galaxies.append(galaxy_id)
#
# print("The", len(passed_galaxies), "passed galaxies:", passed_galaxies)
# print("The", len(excluded_galaxies), "excluded galaxies:", excluded_galaxies)
#
# """
#
# - 32 Galaxies are excluded, 143 galaxies remain in the data set.
# - The results are:
#
# """
# The 143 passed galaxies: ['NGC3917', 'UGC11557', 'IC4202', 'F568-V1', 'UGC08550', 'UGC00128', 'UGC04325', 'NGC6503', 'F563-1', 'UGC02487', 'UGC06930', 'NGC6946', 'UGC08286', 'UGC05716', 'NGC5985', 'DDO168', 'NGC0247', 'NGC0055', 'UGC05750', 'UGC04305', 'NGC0100', 'NGC3741', 'NGC1705', 'NGC4183', 'UGC07399', 'NGC4010', 'NGC7814', 'UGC00191', 'NGC0289', 'UGC03205', 'UGC08490', 'CamB', 'UGC12506', 'UGC05829', 'NGC7331', 'NGC0300', 'NGC2915', 'UGCA442', 'ESO116-G012', 'UGC12632', 'NGC5585', 'UGC04499', 'UGC07151', 'UGC03580', 'NGC0801', 'DDO161', 'NGC3769', 'NGC5371', 'NGC3198', 'UGC07323', 'NGC2366', 'UGC06667', 'NGC2976', 'DDO154', 'UGC07577', 'NGC4559', 'UGC05918', 'UGC07603', 'UGC08699', 'UGC05005', 'UGC05986', 'UGC02259', 'UGC11820', 'NGC3726', 'F568-1', 'UGC12732', 'DDO170', 'NGC6015', 'UGC01281', 'NGC5055', 'NGC4157', 'UGC06973', 'NGC3877', 'ESO079-G014', 'NGC3972', 'F568-3', 'UGC07089', 'NGC0024', 'F571-8', 'NGC3893', 'NGC2841', 'UGCA444', 'UGC11914', 'KK98-251', 'UGC06614', 'NGC4214', 'D631-7', 'UGC11455', 'UGC08837', 'NGC4100', 'NGC7793', 'NGC2683', 'UGC05721', 'NGC1090', 'NGC2998', 'UGC06818', 'NGC5907', 'NGC1003', 'NGC6195', 'UGC06399', 'NGC4088', 'NGC4013', 'IC2574', 'F563-V2', 'NGC6674', 'UGC06983', 'UGC02916', 'F583-1', 'UGC07524', 'DDO064', 'NGC2903', 'UGC02953', 'UGC09133', 'UGC06786', 'UGC05253', 'NGC0891', 'UGC06917', 'ESO563-G021', 'UGC01230', 'UGC07125', 'NGC3521', 'UGC05764', 'NGC2403', 'UGC02455', 'NGC5033', 'F583-4', 'NGC5005', 'NGC4217', 'F579-V1', 'NGC2955', 'UGC07608', 'UGC03546', 'F574-1', 'NGC3109', 'NGC3992', 'UGC02885', 'UGC04483', 'UGC04278', 'NGC3953', 'UGC06446', 'UGC09037', 'UGC00731', 'UGC06787']
#
# The 32 excluded galaxies: ['NGC4389', 'UGC05999', 'ESO444-G084', 'NGC4051', 'F567-2', 'UGC06923', 'NGC4138', 'F561-1', 'F574-2', 'NGC6789', 'UGC07261', 'UGC00891', 'UGC05414', 'UGC00634', 'UGC07690', 'UGC07866', 'F565-V2', 'UGC02023', 'UGC07559', 'UGCA281', 'PGC51017', 'NGC3949', 'UGC10310', 'D564-8', 'NGC4085', 'D512-2', 'F563-V1', 'UGC06628', 'UGC09992', 'UGC07232', 'F571-V1', 'NGC4068']
# """

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# - As seen on the eight plots, the jeans fit is not perfect on the used galaxies. It differs mainly on the beginning or at the end. Especially for high or low c and M200 values, the plot is mainly linear. Its not good for plotting a rotation curve.
#
# - For the related c, it was necessary to change r1 for a good fit. r1 = 4.35 worked good for M200 = 1e13.
#
# - Its hard to have general conclusions about fitting the jeans model on different galaxies. For the used two galaxies, the jeans model only worked on one galaxy good enough for Phi_b = None.
#
# - For these two galaxies, not every M200 and c worked. Some values couldn't plot at all. The plot is for a lot values mostly linear and not formed like a curve at all.
#
# - The Numbers of galaxies could be reduced by 32 galaxies.
# - Code by ASOrlik like "readData.py" [4] helped for the galaxyID cut.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# - Find out and inform more about the virial velocity [2] to exclude more galaxies from the cut data set. 143 galaxies are still to much and more galaxies have to be cut out.
#
# - Exclude more galaxies from the remaining galaxies: Model the baryonic distribution with a single hernquist profile and exclude galaxies that show clear evidence of a disk and bulge. Also exclude galaxies with a poor hernquist profile. (see [1]).
#
#
# - Write emcee script for the jeans model and work with it

# %% [markdown]
# # 5. Bibliography
#
# Your references here

# %%
# [1]: "An Enhanced Isothermal Jeans Approach to Constraining Dark Matter Self-Interactions from Galactic Kinematics" by Zixiang Jia1, Fangzhou Jiang, Shubo Li, Ran Li, Jing Wang and Ling Zhu
# Submitted on 23.01.2026
# https://arxiv.org/abs/2601.17118

# [2]: "THE SMALL SCATTER OF THE BARYONIC TULLY–FISHER RELATION" by Federico Lelli1, Stacy S. McGaugh and James M. Schombert
# Published on 04.01.2016
# https://iopscience.iop.org/article/10.3847/2041-8205/816/1/L14


# [3]: Documentation about emcee
# https://emcee.readthedocs.io/en/stable/

# [4]: sidm-rotation-curves-SPARC by ASOrlik
# last update on 2026
# https://github.com/AdamSmithOrlik/sidm-rotation-curves-SPARC

# [5]: "Cold dark matter haloes in the Planck era: evolution of structural parameters for Einasto and NFW profiles" by Aaron A. Dutton and Andrea V. Macciò
# Submitted on 29.04.2014
# https://arxiv.org/abs/1402.7073
